# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 5))

ax1.set_title('PPO-CNN Breakout Training Curve for Avg Reward (500k iterations)')
ax1.set_xlabel('Timesteps')
ax1.set_ylabel('Avg Reward')
ax1.set_ylim(top=8.6)

log_path = "../logs/ppo_cnn/breakout/lr_1e-4_clip_01/500k/ppo_cnn.csv"
df = pd.read_csv(log_path)

ax1.plot(df['step'], df['avg_reward'], label='lr=1e-4, clip=0.1')

log_path = "../logs/ppo_cnn/breakout/lr_1e-4_clip_02/500k/ppo_cnn.csv"
df = pd.read_csv(log_path)

ax1.plot(df['step'], df['avg_reward'], label='lr=1e-4, clip=0.2')

# ======================================================================

log_path = "../logs/ppo_cnn/breakout/lr_1e-5_clip_01/500k/ppo_cnn.csv"
df = pd.read_csv(log_path)

ax1.plot(df['step'], df['avg_reward'], label='lr=1e-5, clip=0.1')

log_path = "../logs/ppo_cnn/breakout/lr_1e-5_clip_02/500k/ppo_cnn.csv"
df = pd.read_csv(log_path)

ax1.plot(df['step'], df['avg_reward'], label='lr=1e-5, clip=0.2')

# ======================================================================

log_path = "../logs/ppo_cnn/breakout/lr_1e-6_clip_01/500k/ppo_cnn.csv"
df = pd.read_csv(log_path)

ax1.plot(df['step'], df['avg_reward'], label='lr=1e-6, clip=0.1')

log_path = "../logs/ppo_cnn/breakout/lr_1e-6_clip_02/500k/ppo_cnn.csv"
df = pd.read_csv(log_path)

ax1.plot(df['step'], df['avg_reward'], label='lr=1e-6, clip=0.2')

ax1.grid(True)
ax1.legend()

# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

ax2.set_title('PPO-ViT Breakout Training Curve for Avg Reward (500k iterations)')
ax2.set_ylim(top=8.6)

log_path = "../logs/ppo_vit/breakout/lr_1e-4_clip_01/500k/ppo_vit.csv"
df = pd.read_csv(log_path)

ax2.plot(df['step'], df['avg_reward'], label='lr=1e-4, clip=0.1')

log_path = "../logs/ppo_vit/breakout/lr_1e-4_clip_02/500k/ppo_vit.csv"
df = pd.read_csv(log_path)

ax2.plot(df['step'], df['avg_reward'], label='lr=1e-4, clip=0.2')

# ======================================================================

log_path = "../logs/ppo_vit/breakout/lr_1e-5_clip_01/500k/ppo_vit.csv"
df = pd.read_csv(log_path)

ax2.plot(df['step'], df['avg_reward'], label='lr=1e-5, clip=0.1')

log_path = "../logs/ppo_vit/breakout/lr_1e-5_clip_02/500k/ppo_vit.csv"
df = pd.read_csv(log_path)

ax2.plot(df['step'], df['avg_reward'], label='lr=1e-5, clip=0.2')

# ======================================================================

log_path = "../logs/ppo_vit/breakout/lr_1e-6_clip_01/500k/ppo_vit.csv"
df = pd.read_csv(log_path)

ax2.plot(df['step'], df['avg_reward'], label='lr=1e-6, clip=0.1')

log_path = "../logs/ppo_vit/breakout/lr_1e-6_clip_02/500k/ppo_vit.csv"
df = pd.read_csv(log_path)

ax2.plot(df['step'], df['avg_reward'], label='lr=1e-6, clip=0.2')

ax2.grid(True)
ax2.legend()

plt.tight_layout()
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 5))

ax1.set_title('PPO-CNN Breakout Training Curve for Avg Reward (1mi iterations)')
ax1.set_xlabel('Timesteps')
ax1.set_ylabel('Avg Reward')
ax1.set_ylim(top=11.5)

log_path = "../logs/ppo_cnn/breakout/lr_1e-4_clip_01/1mi/ppo_cnn.csv"
df = pd.read_csv(log_path)

ax1.plot(df['step'], df['avg_reward'], label='lr=1e-4, clip=0.1')

log_path = "../logs/ppo_cnn/breakout/lr_1e-4_clip_02/1mi/ppo_cnn.csv"
df = pd.read_csv(log_path)

ax1.plot(df['step'], df['avg_reward'], label='lr=1e-4, clip=0.2')

# ======================================================================

log_path = "../logs/ppo_cnn/breakout/lr_1e-5_clip_01/1mi/ppo_cnn.csv"
df = pd.read_csv(log_path)

ax1.plot(df['step'], df['avg_reward'], label='lr=1e-5, clip=0.1')

log_path = "../logs/ppo_cnn/breakout/lr_1e-5_clip_02/1mi/ppo_cnn.csv"
df = pd.read_csv(log_path)

ax1.plot(df['step'], df['avg_reward'], label='lr=1e-5, clip=0.2')

# ======================================================================

log_path = "../logs/ppo_cnn/breakout/lr_1e-6_clip_01/1mi/ppo_cnn.csv"
df = pd.read_csv(log_path)

ax1.plot(df['step'], df['avg_reward'], label='lr=1e-6, clip=0.1')

log_path = "../logs/ppo_cnn/breakout/lr_1e-6_clip_02/1mi/ppo_cnn.csv"
df = pd.read_csv(log_path)

ax1.plot(df['step'], df['avg_reward'], label='lr=1e-6, clip=0.2')

ax1.grid(True)
ax1.legend()

# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

ax2.set_title('PPO-ViT Breakout Training Curve for Avg Reward (1mi iterations)')
ax2.set_ylim(top=11.5)

log_path = "../logs/ppo_vit/breakout/lr_1e-4_clip_01/1mi/ppo_vit.csv"
df = pd.read_csv(log_path)

ax2.plot(df['step'], df['avg_reward'], label='lr=1e-4, clip=0.1')

log_path = "../logs/ppo_vit/breakout/lr_1e-4_clip_02/1mi/ppo_vit.csv"
df = pd.read_csv(log_path)

ax2.plot(df['step'], df['avg_reward'], label='lr=1e-4, clip=0.2')

# ======================================================================

log_path = "../logs/ppo_vit/breakout/lr_1e-5_clip_01/1mi/ppo_vit.csv"
df = pd.read_csv(log_path)

ax2.plot(df['step'], df['avg_reward'], label='lr=1e-5, clip=0.1')

log_path = "../logs/ppo_vit/breakout/lr_1e-5_clip_02/1mi/ppo_vit.csv"
df = pd.read_csv(log_path)

ax2.plot(df['step'], df['avg_reward'], label='lr=1e-5, clip=0.2')

# ======================================================================

log_path = "../logs/ppo_vit/breakout/lr_1e-6_clip_01/1mi/ppo_vit.csv"
df = pd.read_csv(log_path)

ax2.plot(df['step'], df['avg_reward'], label='lr=1e-6, clip=0.1')

log_path = "../logs/ppo_vit/breakout/lr_1e-6_clip_02/1mi/ppo_vit.csv"
df = pd.read_csv(log_path)

ax2.plot(df['step'], df['avg_reward'], label='lr=1e-6, clip=0.2')

ax2.grid(True)
ax2.legend()

plt.tight_layout()
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 5))

ax1.set_title('PPO-CNN Breakout Training Curve for Avg Reward (2mi iterations)')
ax1.set_xlabel('Timesteps')
ax1.set_ylabel('Avg Reward')
ax1.set_ylim(top=17)

log_path = "../logs/ppo_cnn/breakout/lr_1e-4_clip_01/2mi/ppo_cnn.csv"
df = pd.read_csv(log_path)

ax1.plot(df['step'], df['avg_reward'], label='lr=1e-4, clip=0.1')

log_path = "../logs/ppo_cnn/breakout/lr_1e-4_clip_02/2mi/ppo_cnn.csv"
df = pd.read_csv(log_path)

ax1.plot(df['step'], df['avg_reward'], label='lr=1e-4, clip=0.2')

# ======================================================================

log_path = "../logs/ppo_cnn/breakout/lr_1e-5_clip_01/2mi/ppo_cnn.csv"
df = pd.read_csv(log_path)

ax1.plot(df['step'], df['avg_reward'], label='lr=1e-5, clip=0.1')

log_path = "../logs/ppo_cnn/breakout/lr_1e-5_clip_02/2mi/ppo_cnn.csv"
df = pd.read_csv(log_path)

ax1.plot(df['step'], df['avg_reward'], label='lr=1e-5, clip=0.2')

# ======================================================================

log_path = "../logs/ppo_cnn/breakout/lr_1e-6_clip_01/2mi/ppo_cnn.csv"
df = pd.read_csv(log_path)

ax1.plot(df['step'], df['avg_reward'], label='lr=1e-6, clip=0.1')

log_path = "../logs/ppo_cnn/breakout/lr_1e-6_clip_02/2mi/ppo_cnn.csv"
df = pd.read_csv(log_path)

ax1.plot(df['step'], df['avg_reward'], label='lr=1e-6, clip=0.2')

ax1.grid(True)
ax1.legend()

# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

ax2.set_title('PPO-ViT Breakout Training Curve for Avg Reward (2mi iterations)')
ax2.set_ylim(top=17)

log_path = "../logs/ppo_vit/breakout/lr_1e-4_clip_01/2mi/ppo_vit.csv"
df = pd.read_csv(log_path)

ax2.plot(df['step'], df['avg_reward'], label='lr=1e-4, clip=0.1')

log_path = "../logs/ppo_vit/breakout/lr_1e-4_clip_02/2mi/ppo_vit.csv"
df = pd.read_csv(log_path)

ax2.plot(df['step'], df['avg_reward'], label='lr=1e-4, clip=0.2')

# ======================================================================

log_path = "../logs/ppo_vit/breakout/lr_1e-5_clip_01/2mi/ppo_vit.csv"
df = pd.read_csv(log_path)

ax2.plot(df['step'], df['avg_reward'], label='lr=1e-5, clip=0.1')

log_path = "../logs/ppo_vit/breakout/lr_1e-5_clip_02/2mi/ppo_vit.csv"
df = pd.read_csv(log_path)

ax2.plot(df['step'], df['avg_reward'], label='lr=1e-5, clip=0.2')

# ======================================================================

log_path = "../logs/ppo_vit/breakout/lr_1e-6_clip_01/2mi/ppo_vit.csv"
df = pd.read_csv(log_path)

ax2.plot(df['step'], df['avg_reward'], label='lr=1e-6, clip=0.1')

log_path = "../logs/ppo_vit/breakout/lr_1e-6_clip_02/2mi/ppo_vit.csv"
df = pd.read_csv(log_path)

ax2.plot(df['step'], df['avg_reward'], label='lr=1e-6, clip=0.2')

ax2.grid(True)
ax2.legend()

plt.tight_layout()
plt.show()
