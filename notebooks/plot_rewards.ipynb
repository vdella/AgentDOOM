# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
plt.figure(figsize=(10, 5))

plt.title('PPO-CNN Breakout Training Curve for Avg Reward (500k iterations)')
plt.xlabel('Timesteps')
plt.ylabel('Avg Reward')

log_path = "../logs/lr_1e-6_clip_02/ppo_cnn_breakout_500k_iterations.csv"
df = pd.read_csv(log_path)

plt.plot(df['step'], df['avg_reward'], label='lr=1e-6, clip=0.2')

log_path = "../logs/lr_25e-4_clip_02/ppo_cnn_breakout_500k_iterations.csv"
df = pd.read_csv(log_path)

plt.plot(df['step'], df['avg_reward'], label='lr=2.5e-4, clip=0.2')

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
log_path = "../logs/lr_1e-6_clip_02/ppo_cnn_breakout_1mi_iterations.csv"
df = pd.read_csv(log_path)
df.head()
# Out:
#     step  avg_reward
# 0   2048     1.40000
# 1   4096     1.50000
# 2   6144     1.50000
# 3   8192     1.47619
# 4  10240     1.37037

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['step'], df['avg_reward'], label='lr=1e-6, clip=0.2')
plt.xlabel('Timesteps')
plt.ylabel('Avg Reward')
plt.title('PPO-CNN Tetris Training Curve Avg Reward (1 million iterations)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
log_path = "../logs/lr_1e-6_clip_02/ppo_cnn_breakout_2mi_iterations.csv"
df = pd.read_csv(log_path)
df.head()
# Out:
#     step  avg_reward
# 0   2048    1.090909
# 1   4096    1.173913
# 2   6144    1.147059
# 3   8192    1.065217
# 4  10240    1.122807

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['step'], df['avg_reward'], label='lr=1e-6, clip=0.2')
plt.xlabel('Timesteps')
plt.ylabel('Avg Reward')
plt.title('PPO-CNN Tetris Training Curve Avg Reward (2 million iterations)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
