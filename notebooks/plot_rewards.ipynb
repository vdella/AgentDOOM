# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
log_path = "../logs/ppo_cnn_breakout_500k_iterations.csv"
df = pd.read_csv(log_path)
df.head()
# Out:
#     step  avg_reward
# 0   2048    1.400000
# 1   4096    1.476190
# 2   6144    1.406250
# 3   8192    1.585366
# 4  10240    1.588235

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['step'], df['avg_reward'], label='Avg Reward (100 eps)')
plt.xlabel('Timesteps')
plt.ylabel('Avg Reward')
plt.title('PPO-CNN Breakout Training Curve')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
log_path = "../logs/ppo_cnn_breakout_1mi_iterations.csv"
df = pd.read_csv(log_path)
df.head()
# Out:
#     step  avg_reward
# 0   2048    0.240741
# 1   4096    0.240000
# 2   6144    0.270000
# 3   8192    0.270000
# 4  10240    0.350000

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['step'], df['avg_reward'], label='Avg Reward (100 eps)')
plt.xlabel('Timesteps')
plt.ylabel('Avg Reward')
plt.title('PPO-CNN Tetris Training Curve for 1 million iterations')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
log_path = "../logs/ppo_cnn.csv"
df = pd.read_csv(log_path)
df.head()
# Out:
#     step  avg_reward
# 0   2048         0.0
# 1   4096         0.0
# 2   6144         0.0
# 3   8192         0.0
# 4  10240         0.0

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['step'], df['avg_reward'], label='Avg Reward (100 eps)')
plt.xlabel('Timesteps')
plt.ylabel('Avg Reward')
plt.title('PPO-CNN Tetris Training Curve')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
log_path = "../logs/ppo_vit.csv"
df = pd.read_csv(log_path)
df.head()

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['step'], df['avg_reward'], label='Avg Reward (100 eps)')
plt.xlabel('Timesteps')
plt.ylabel('Avg Reward')
plt.title('PPO-ViT Tetris Training Curve')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
